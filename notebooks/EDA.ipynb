# %% [markdown]
# # Exploratory Data Analysis
# Analyze trends in patient admissions, financials, and operations.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# df = pd.read_csv('data/clean.csv')
# df.describe()
