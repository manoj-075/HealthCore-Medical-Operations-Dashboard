# %% [markdown]
# # Data Cleaning
# Clean and preprocess raw medical operations data.

# %%
import pandas as pd

# Load raw data
# df = pd.read_csv('data/raw.csv')
# df.dropna(inplace=True)
# df.to_csv('data/clean.csv', index=False)
